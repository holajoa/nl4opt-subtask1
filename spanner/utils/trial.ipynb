# %%
import json

# %%
data = {
    'O':0, 
    'VAR':1, 
    'CONST_DIR':2, 
    'LIMIT':3, 
    'OBJ_DIR':4, 
    'OBJ_NAME':5, 
    'PARAM':6, 
}

# %%
with open('../data/label2idx.json', 'w') as fp:
    json.dump(data, fp)

# %%
import torch

# %%
torch.load('../weight.pt')
# Out:
# tensor([[ 1.0615e-02, -6.4007e-03,  6.5528e-03, -3.3205e-03, -1.0169e-02,
#           1.5419e-02,  1.9878e-02,  1.9149e-03,  9.1002e-03, -1.4222e-02,
#           3.3794e-02,  1.1234e-02,  2.8120e-02,  1.3131e-02,  6.8117e-03,
#           6.3116e-03, -2.0196e-03, -8.4413e-03,  2.4377e-02,  1.1416e-03,
#           2.4904e-02, -3.3035e-02,  1.5998e-02,  1.2940e-02, -9.7477e-03,
#           1.5984e-02, -4.0747e-02,  8.5184e-03,  4.1942e-02, -4.7957e-02,
#           4.5715e-03,  6.2455e-03, -2.8708e-02,  2.1792e-02, -1.6984e-02,
#          -5.2281e-02,  2.3529e-02,  6.1105e-03, -2.2907e-02, -1.6989e-02,
#          -4.9757e-02, -3.6136e-02, -4.3550e-03,  2.7905e-02,  8.9459e-03,
#          -1.3626e-02,  4.8727e-03,  6.1834e-03,  1.1248e-02, -6.6382e-03,
#          -2.0744e-02, -4.4202e-02, -5.3097e-04, -1.4509e-02, -8.7456e-04,
#           1.0922e-02, -1.9331e-02,  1.1810e-02,  2.6297e-02,  7.1664e-03,
#          -8.2474e-03, -4.4642e-02, -4.4117e-02,  2.5741e-02, -1.4580e-02,
# ...
