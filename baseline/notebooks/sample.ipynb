# %%
import pandas as pd

def full_display(df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', 10):
        display(df)

# %%
_, tokens, pred, true = pd.read_csv('sample.txt', header=None, sep='\t').values.T
' '.join(tokens)
# Out:
# 'the Standard , Plus , and Premium grades respectively .'

# %%
df = pd.read_csv('./test_base_roberta_squad2_lr_2e-5_timestamp_1663584495.1579309_final_analysis.csv', index_col=0)
full_display(df)
# Out:
#                token         pred         true
# 0               Bold            O            O
# 1             Tycoon            O            O
# 2              wants            O            O
# 3                 to            O            O
# 4                put            O            O
# 5                his            O            O
# 6                  $            O            O
# 7             10,000      B-LIMIT      B-LIMIT
# 8                 to            O            O
# 9               work            O            O
# 10               and            O            O
# 11           decides            O            O
# 12                to            O            O
# 13            invest            O  B-CONST_DIR
# 14               his            O            O
# 15             money            O            O
# 16                in            O            O
# 17              GICs        B-VAR        B-VAR
# 18               and            O            O
# ...
